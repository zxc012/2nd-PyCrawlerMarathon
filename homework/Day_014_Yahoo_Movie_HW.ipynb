label>
# <input class="gabtn" data-cinema="40288eb0050f542401050f55532606b5" data-date="1583856000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie="baaaceb372b14546a979935c62069bd2" data-movie_date="03.11" data-movie_time="19:00" data-movie_title="罪樂園" data-movie_type="數位" data-session="159f369fedb241edb4110e2a289adadc" data-time="1583924400" id="73311238" name="schedule_list" type="radio" value="2020-03-11 19:00:00"/>
# <label class="select" for="73311238">19:00</label>
# <input class="gabtn" data-cinema="40288eb0050f542401050f55532606b5" data-date="1583856000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie="baaaceb372b14546a979935c62069bd2" data-movie_date="03.11" data-movie_time="23:10" data-movie_title="罪樂園" data-movie_type="數位" data-session="d70697bd4add46f9bdee39dd4dd5c6d5" data-time="1583939400" id="73311239" name="schedule_list" type="radio" value="2020-03-11 23:10:00"/>
# <label class="select" for="73311239">23:10</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="台北信義威秀影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=45" data-theater_url="http://www.vscinemas.com.tw/" id="theater_id_45">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=45">台北信義威秀影城</a>
# <span>02-87805566</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1583856000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie="98bab35a44d04ab2a3356be71162f4af" data-movie_date="03.11" data-movie_time="15:00" data-movie_title="罪樂園" data-movie_type="數位" data-session="c9c7df099cd64fc4929ec164938fe697" data-time="1583910000" id="73298184" name="schedule_list" type="radio" value="2020-03-11 15:00:00"/>
# <label class="select" for="73298184">15:00</label>
# <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1583856000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie="98bab35a44d04ab2a3356be71162f4af" data-movie_date="03.11" data-movie_time="20:35" data-movie_title="罪樂園" data-movie_type="數位" data-session="95a85f0078454f34a9b38c5ac9572e09" data-time="1583930100" id="73293485" name="schedule_list" type="radio" value="2020-03-11 20:35:00"/>
# <label class="select" for="73293485">20:35</label>
# <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1583856000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie="98bab35a44d04ab2a3356be71162f4af" data-movie_date="03.11" data-movie_time="23:00" data-movie_title="罪樂園" data-movie_type="數位" data-session="4e776ad85d27448e97b6c28a2780ea77" data-time="1583938800" id="73293486" name="schedule_list" type="radio" value="2020-03-11 23:00:00"/>
# <label class="select" for="73293486">23:00</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="百老匯數位影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=52" data-theater_url="http://www.broadway-cineplex.com.tw/index.asp" id="theater_id_52">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=52">百老匯數位影城</a>
# <span>02-86636128</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie_date="03.11" data-movie_time="09:50" data-movie_title="罪樂園" data-movie_type="數位" data-news="news" id="73321497" name="schedule_list" type="radio" value="2020-03-11 09:50:00"/>
# <label class="" for="73321497">09:50</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie_date="03.11" data-movie_time="12:10" data-movie_title="罪樂園" data-movie_type="數位" data-news="news" id="73321498" name="schedule_list" type="radio" value="2020-03-11 12:10:00"/>
# <label class="" for="73321498">12:10</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie_date="03.11" data-movie_time="14:30" data-movie_title="罪樂園" data-movie_type="數位" data-news="news" id="73321499" name="schedule_list" type="radio" value="2020-03-11 14:30:00"/>
# <label class="select" for="73321499">14:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie_date="03.11" data-movie_time="16:50" data-movie_title="罪樂園" data-movie_type="數位" data-news="news" id="73321500" name="schedule_list" type="radio" value="2020-03-11 16:50:00"/>
# <label class="select" for="73321500">16:50</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie_date="03.11" data-movie_time="19:10" data-movie_title="罪樂園" data-movie_type="數位" data-news="news" id="73321501" name="schedule_list" type="radio" value="2020-03-11 19:10:00"/>
# <label class="select" for="73321501">19:10</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie_date="03.11" data-movie_time="21:30" data-movie_title="罪樂園" data-movie_type="數位" data-news="news" id="73321502" name="schedule_list" type="radio" value="2020-03-11 21:30:00"/>
# <label class="select" for="73321502">21:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie_date="03.11" data-movie_time="23:50" data-movie_title="罪樂園" data-movie_type="數位" data-news="news" id="73321503" name="schedule_list" type="radio" value="2020-03-11 23:50:00"/>
# <label class="select" for="73321503">23:50</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="今日秀泰影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=112" data-theater_url="http://showtimes.pixnet.net/blog" id="theater_id_112">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=112">今日秀泰影城</a>
# <span>02-23751669</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie_date="03.11" data-movie_time="11:00" data-movie_title="罪樂園" data-movie_type="數位" data-news="news" id="73323091" name="schedule_list" type="radio" value="2020-03-11 11:00:00"/>
# <label class="" for="73323091">11:00</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie_date="03.11" data-movie_time="15:40" data-movie_title="罪樂園" data-movie_type="數位" data-news="news" id="73323092" name="schedule_list" type="radio" value="2020-03-11 15:40:00"/>
# <label class="select" for="73323092">15:40</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie_date="03.11" data-movie_time="20:20" data-movie_title="罪樂園" data-movie_type="數位" data-news="news" id="73323093" name="schedule_list" type="radio" value="2020-03-11 20:20:00"/>
# <label class="select" for="73323093">20:20</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie_date="03.11" data-movie_time="22:50" data-movie_title="罪樂園" data-movie_type="數位" data-news="news" id="73323094" name="schedule_list" type="radio" value="2020-03-11 22:50:00"/>
# <label class="select" for="73323094">22:50</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="誠品電影院" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=168" data-theater_url="https://meet.eslite.com/tw/tc/gallery/201803020001" id="theater_id_168">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=168">誠品電影院</a>
# <span>02-66365888</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie_date="03.11" data-movie_time="14:00" data-movie_title="罪樂園" data-movie_type="數位" data-news="news" id="73323411" name="schedule_list" type="radio" value="2020-03-11 14:00:00"/>
# <label class="select" for="73323411">14:00</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie_date="03.11" data-movie_time="20:55" data-movie_title="罪樂園" data-movie_type="數位" data-news="news" id="73323412" name="schedule_list" type="radio" value="2020-03-11 20:55:00"/>
# <label class="select" for="73323412">20:55</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="喜樂時代影城南港店" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=186" data-theater_url="http://www.centuryasia.com.tw/default.aspx" id="theater_id_186">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=186">喜樂時代影城南港店</a>
# <span>02-27888185</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1583856000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie="0ec520df535241c094ad8c1844b31846" data-movie_date="03.11" data-movie_time="15:20" data-movie_title="罪樂園" data-movie_type="數位" data-session="7fda0a68824d45c2a3f8d0863ac6c03d" data-time="1583911200" id="73296937" name="schedule_list" type="radio" value="2020-03-11 15:20:00"/>
# <label class="select" for="73296937">15:20</label>
# <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1583856000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie="0ec520df535241c094ad8c1844b31846" data-movie_date="03.11" data-movie_time="17:45" data-movie_title="罪樂園" data-movie_type="數位" data-session="c2e655364dd64606b94988f37fda0d4f" data-time="1583919900" id="73296938" name="schedule_list" type="radio" value="2020-03-11 17:45:00"/>
# <label class="select" for="73296938">17:45</label>
# <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1583856000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '罪樂園']" data-movie="0ec520df535241c094ad8c1844b31846" data-movie_date="03.11" data-movie_time="20:10" data-movie_title="罪樂園" data-movie_type="數位" data-session="f19ee21a4ba247c3afd5936ab0bc1ae5" data-time="1583928600" id="73296939" name="schedule_list" type="radio" value="2020-03-11 20:10:00"/>
# <label class="select" for="73296939">20:10</label>
# </div>
# </li>
# </ul>]

# %%
for h in html:
    print('----------------------------------------------------------------------')
    print('電影院:  %s' % (h['data-theater_name']))
    print('放映類型: %s' % (h.find('span',class_='tapR').text))
    movies_info = h.find_all('input')
    for movie_info in movies_info:
        print(movie_info['value'])
# Out:
# ----------------------------------------------------------------------
# 電影院:  國賓影城(台北長春廣場)
# 放映類型: 數位
# 2020-03-11 15:00:00
# 2020-03-11 19:25:00
# 2020-03-11 21:50:00
# ----------------------------------------------------------------------
# 電影院:  喜滿客絕色影城
# 放映類型: 數位
# 2020-03-11 14:45:00
# 2020-03-11 19:00:00
# 2020-03-11 23:10:00
# ----------------------------------------------------------------------
# 電影院:  台北信義威秀影城
# 放映類型: 數位
# 2020-03-11 15:00:00
# 2020-03-11 20:35:00
# 2020-03-11 23:00:00
# ----------------------------------------------------------------------
# 電影院:  百老匯數位影城
# 放映類型: 數位
# 2020-03-11 09:50:00
# 2020-03-11 12:10:00
# 2020-03-11 14:30:00
# 2020-03-11 16:50:00
# 2020-03-11 19:10:00
# 2020-03-11 21:30:00
# 2020-03-11 23:50:00
# ----------------------------------------------------------------------
# 電影院:  今日秀泰影城
# 放映類型: 數位
# 2020-03-11 11:00:00
# 2020-03-11 15:40:00
# 2020-03-11 20:20:00
# 2020-03-11 22:50:00
# ----------------------------------------------------------------------
# 電影院:  誠品電影院
# 放映類型: 數位
# 2020-03-11 14:00:00
# 2020-03-11 20:55:00
# ----------------------------------------------------------------------
# 電影院:  喜樂時代影城南港店
# 放映類型: 數位
# 2020-03-11 15:20:00
# 2020-03-11 17:45:00
# 2020-03-11 20:10:00
